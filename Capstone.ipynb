# %%
#Coursera Capstone used mainly for Capstone Project Notebook
Import panda as pd
Import numpy as np
# Out:
#   File "<ipython-input-1-3196309b09bb>", line 2
#     Import pandas as pd
#                 ^
# SyntaxError: invalid syntax
